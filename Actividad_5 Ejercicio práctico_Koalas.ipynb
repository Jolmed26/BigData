# %% [markdown]
# # Ejercicio Práctico de Koalas

# %%
import findspark
findspark.init()

import pandas as pd
import pyspark

# %%
import numpy as np
import pandas as pd
import databricks.koalas as ks
# Out:
# WARNING:root:Found numpy version "1.21.6" installed with pyspark version "2.4.4". Some functions will not work well with this combination of numpy version "1.21.6" and pyspark version "2.4.4". Please try to upgrade pyspark version to 3.1 or above, or downgrade numpy version to below 1.20.
# WARNING:root:'ARROW_PRE_0_15_IPC_FORMAT' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=0.15 and pyspark<3.0. Koalas will set it for you but it does not work if there is a Spark context already launched.
# WARNING:root:'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. Koalas will set it for you but it does not work if there is a Spark context already launched.

# %% [markdown]
# ### Funciones básicas

# %%
pser = pd.Series([1, 3, 5, np.nan, 6, 8])

## Crea una serie de Koalas con [1, 3, 5, np.nan, 6, 8]

kser = ks.Series(pser)

## Pasa la serie de pandas pser a Koalas con el nombre de kser

# %%
kser
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
## Ordena kser por el index
kser.sort_index(ascending=False)
# Out:
# 5    8.0
# 4    6.0
# 3    NaN
# 2    5.0
# 1    3.0
# 0    1.0
# dtype: float64

# %%
pdf = pd.DataFrame({'A': np.random.rand(5),
                    'B': np.random.rand(5)})

## Genera un Dataframe de Koalas con el pdf de pandas y llamalo kdf

kdf = ks.DataFrame(pdf)

kdf
# Out:
#           A         B
# 0  0.896417  0.686852
# 1  0.895669  0.960142
# 2  0.251324  0.065352
# 3  0.662089  0.338328
# 4  0.402244  0.970000

# %% [markdown]
# ### Visualización de datos

# %%
## Describe los datos de kdf

kdf.dtypes
# Out:
# A    float64
# B    float64
# dtype: object

# %%
## Ordena los datos de kdf por la columna B
kdf.sort_values(by=["B"])
# Out:
#           A         B
# 2  0.251324  0.065352
# 3  0.662089  0.338328
# 0  0.896417  0.686852
# 1  0.895669  0.960142
# 4  0.402244  0.970000

# %%
## Transpon los datos de kdf
kdf.T
# Out:
#           0         1         2         3         4
# A  0.896417  0.895669  0.251324  0.662089  0.402244
# B  0.686852  0.960142  0.065352  0.338328  0.970000

# %% [markdown]
# ### Selección

# %%
## Selecciona las varaibles A y B de Kdf

kdf.select_dtypes(include=["float64"])
# Out:
#           A         B
# 0  0.896417  0.686852
# 1  0.895669  0.960142
# 2  0.251324  0.065352
# 3  0.662089  0.338328
# 4  0.402244  0.970000

# %%
## Selecciona las varaibles A y B de Kdf

kdf.filter(items=['A', 'B'])
# Out:
#           A         B
# 0  0.896417  0.686852
# 1  0.895669  0.960142
# 2  0.251324  0.065352
# 3  0.662089  0.338328
# 4  0.402244  0.970000

# %%
## Selecciona las filas 1, 2 de kdf
kdf.filter(items=["0","1"], axis=0)
# Out:
#           A         B
# 0  0.896417  0.686852
# 1  0.895669  0.960142

# %%
## Selecciona las filas 0, 1 y 2 de la variable B
kdf.filter(items=["0","1","2"], axis=0).filter(items=["B"])
# Out:
#           B
# 0  0.686852
# 1  0.960142
# 2  0.065352

# %% [markdown]
# ### Aplicando funciones de Python a Koalas

# %%
## Aplica la funcion de Python de np.cumsum a kdf
kdf.cumsum()
# Out:
#           A         B
# 0  0.896417  0.686852
# 1  1.792086  1.646995
# 2  2.043410  1.712347
# 3  2.705500  2.050675
# 4  3.107743  3.020674

# %%
## Eleva al cuadrado los valores de kdf
kdf**2
# Out:
#           A         B
# 0  0.803564  0.471766
# 1  0.802222  0.921874
# 2  0.063164  0.004271
# 3  0.438362  0.114466
# 4  0.161800  0.940899

# %% [markdown]
# ### Agrupando datos

# %%
## Obten la suma de los valores al agrupar por A y por B
kdf.groupby(["A","B"]).sum()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(0.4022435128886278, 0.969999531186327), (0.8964173522163766, 0.6868522068907145), (0.25132448095282267, 0.06535204037955378), (0.6620893168931496, 0.3383279748458323), (0.8956685025699643, 0.9601424517208328)]

# %%
kdf.groupby("A").sum()
# Out:
#                  B
# A
# 0.402244  0.970000
# 0.251324  0.065352
# 0.896417  0.686852
# 0.662089  0.338328
# 0.895669  0.960142

# %%
kdf.groupby(["B"]).sum()
# Out:
#                  A
# B
# 0.065352  0.251324
# 0.970000  0.402244
# 0.338328  0.662089
# 0.686852  0.896417
# 0.960142  0.895669

# %% [markdown]
# ### Generando gráficos

# %%
# This is needed for visualizing plot on notebook
# %matplotlib inline

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant',
         'rabbit', 'giraffe', 'coyote', 'horse']

kdf = ks.DataFrame({'speed': speed,
                   'lifespan': lifespan}, index=index)

## Genera un grafico de barras con kdf y matplotlib

kdf.plot.bar()

# %%
kdf = ks.DataFrame({
    'sales': [3, 2, 3, 9, 10, 6, 3],
    'signups': [5, 5, 6, 12, 14, 13, 9],
    'visits': [20, 42, 28, 62, 81, 50, 90],
}, index=pd.date_range(start='2019/08/15', end='2020/03/09',
                       freq='M'))

## Genera un grafico de areas con kdf y matplotlib

kdf.sales.plot.area()

# %% [markdown]
# ### Utilizando SQL en Koalas

# %%
kdf = ks.DataFrame({'year': [1990, 1997, 2003, 2009, 2014],
                    'pig': [20, 18, 489, 675, 1776],
                    'horse': [4, 25, 281, 600, 1900]})

# %%
## Con una consulta SQL selecciona los datos donde pig sea mayor que 100

kdf[kdf['pig'] > 100]
# Out:
#    year   pig  horse
# 2  2003   489    281
# 3  2009   675    600
# 4  2014  1776   1900

# %%
pdf = ks.DataFrame({'year': [1990, 1997, 2003, 2009, 2014],
                    'sheep': [22, 50, 121, 445, 791],
                    'chicken': [250, 326, 589, 1241, 2118]})

# %%
## Haz un inner join entre kdf y pdf en la vriable year, selecciona el pig y el chicken
## ordena los datos por pig y chicken

join_kdf = kdf.set_index('year').join(pdf.set_index('year'))
join_kdf.sort_values(by=join_kdf.columns).filter(items=["pig", "chicken"])
# Out:
#        pig  chicken
# year
# 1997    18      326
# 1990    20      250
# 2003   489      589
# 2009   675     1241
# 2014  1776     2118

# %%
from pyspark.sql import SparkSession

# %% [markdown]
# ### Trabajando con PySpark

# %%
kdf = ks.DataFrame({'A': [1, 2, 3, 4, 5], 'B': [10, 20, 30, 40, 50]})

## Convierete el dataframe de Koalas a Dataframe de Spark

spark = SparkSession.builder.getOrCreate()

df_spark = kdf.to_spark()

# %%
## muestra los datos
df_spark.show()
# Out:
# +---+---+
# |  A|  B|
# +---+---+
# |  1| 10|
# |  2| 20|
# |  3| 30|
# |  4| 40|
# |  5| 50|
# +---+---+
